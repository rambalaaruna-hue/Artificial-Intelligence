# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score,GridSearchCV

import sklearn.metrics as metrics

import category_encoders as metrics

import category_encoders as ce
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv(r"C:\Users\ramba\OneDrive\Documents\AI\Lab 21 House_Rent_Dataset.csv")
data.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# ...

# %%
data = data.drop(['Posted on','Floor','Area Locality'], axis=1,errors='ignore')
data
# Out:
#        Posted On  BHK   Rent  Size    Area Type       City Furnishing Status  \
# 0     2022-05-18    2  10000  1100   Super Area    Kolkata       Unfurnished
# 1     2022-05-13    2  20000   800   Super Area    Kolkata    Semi-Furnished
# 2     2022-05-16    2  17000  1000   Super Area    Kolkata    Semi-Furnished
# 3     2022-07-04    2  10000   800   Super Area    Kolkata       Unfurnished
# 4     2022-05-09    2   7500   850  Carpet Area    Kolkata       Unfurnished
# ...          ...  ...    ...   ...          ...        ...               ...
# 4741  2022-05-18    2  15000  1000  Carpet Area  Hyderabad    Semi-Furnished
# 4742  2022-05-15    3  29000  2000   Super Area  Hyderabad    Semi-Furnished
# 4743  2022-07-10    3  35000  1750  Carpet Area  Hyderabad    Semi-Furnished
# 4744  2022-07-06    3  45000  1500  Carpet Area  Hyderabad    Semi-Furnished
# 4745  2022-05-04    2  15000  1000  Carpet Area  Hyderabad       Unfurnished
#
# ...

# %%
# !pip install category-encoders

# %%
categorical_cols = data.select_dtypes(include="object").columns
categorical_cols
# Out:
# Index(['Posted On', 'Area Type', 'City', 'Furnishing Status',
#        'Tenant Preferred', 'Point of Contact'],
#       dtype='object')

# %%
for col in categorical_cols:
    print(f"{col}:{data[col].nunique()}")
# Out:
# Posted On:81
# Area Type:3
# City:6
# Furnishing Status:3
# Tenant Preferred:3
# Point of Contact:3

# %%
x=data.drop(columns="Rent")
y=data["Rent"]

# %%
encoder = ce.LeaveOneOutEncoder(return_df=True)
x=encoder.fit_transform(x,y)

# %%
x.head()
# Out:
#       Posted On  BHK  Size     Area Type          City  Furnishing Status  \
# 0  49986.301370    2  1100  18676.943967  11648.319312       22468.505513
# 1  33369.521739    2   800  18672.853988  11629.198853       38727.130222
# 2  22156.603774    2  1000  18674.080982  11634.934990       38728.463556
# 3  36085.321101    2   800  18676.943967  11648.319312       22468.505513
# 4  15857.142857    2   850  52405.438398  11653.099426       22469.883682
#
#    Tenant Preferred  Bathroom  Point of Contact
# 0      31216.953238         2      16706.291757
# 1      31214.048795         1      16703.181337
# 2      31214.920128         1      16704.114463
# 3      31216.953238         1      16706.291757
# 4      42185.583836         1      16707.069362

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x = scaler.fit_transform(x)

# %%
x_df = pd.DataFrame(x)
x_df
# Out:
#              0    1         2         3         4         5         6  \
# 0     0.455100  0.2  0.136421  0.273162  0.004388  0.009553  0.017960
# 1     0.270592  0.2  0.098874  0.273074  0.004130  0.487075  0.017809
# 2     0.146087  0.2  0.123905  0.273100  0.004207  0.487114  0.017854
# 3     0.300748  0.2  0.098874  0.273162  0.004388  0.009553  0.017960
# 4     0.076140  0.2  0.105131  0.999941  0.004452  0.009593  0.587919
# ...        ...  ...       ...       ...       ...       ...       ...
# 4741  0.454339  0.2  0.123905  0.999871  0.124704  0.487140  0.017884
# 4742  0.069530  0.4  0.249061  0.272994  0.124486  0.486957  0.017673
# 4743  0.352491  0.4  0.217772  0.999683  0.124392  0.486879  0.017582
# 4744  0.433114  0.4  0.186483  0.999589  0.124236  0.486748  0.995587
# 4745  0.116897  0.2  0.123905  0.999871  0.124704  0.009472  0.587449
#
#              7         8
# 0     0.111111  0.003219
# 1     0.000000  0.003165
# 2     0.000000  0.003181
# ...
