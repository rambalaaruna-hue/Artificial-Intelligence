# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
c = [i for i in range(1,len(y_test)+1,1)]
plt.plot(c,y_test,color+'r',linestyle='-')
plt.plot(c,y_pred,color='b',linestyle='-')
plt.xlable('Salary')
plt.ylable('index')
plt.title('Prediction')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 c = [i for i in range(1,len(y_test)+1,1)]
#       2 plt.plot(c,y_test,color+'r',linestyle='-')
#       3 plt.plot(c,y_pred,color='b',linestyle='-')
#
# NameError: name 'y_test' is not defined

# %%
from sklearn.metrics import r2_score,mean_sqared_error
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from sklearn.metrics import r2_score,mean_sqared_error
#
# ImportError: cannot import name 'mean_sqared_error' from 'sklearn.metrics' (c:\Users\ramba\anaconda3\Lib\site-packages\sklearn\metrics\__init__.py)

# %%
mse = mean_squared_error(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 mse = mean_squared_error(y_test,y_pred)
#
# NameError: name 'mean_squared_error' is not defined

# %%
rsq = r2_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 rsq = r2_score(y_test,y_pred)
#
# NameError: name 'y_test' is not defined

# %%
print('mean squared error:',mse)
print('r square :',rsq)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print('mean squared error:',mse)
#       2 print('r square :',rsq)
#
# NameError: name 'mse' is not defined

# %%
plt.figure(figsize=(12,6))
plt.sactter(y_test,y_pred,color='r',linestyle='-')
