# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\ramba\OneDrive\Documents\AI\SelfPracticeSalary_Data.csv")

df = pd.DataFrame(df)
print(df)
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
X = df["YearsExperience"]
y = df["Salary"]

print(x)
print(y)
# Out:
# 0      1.1
# 1      1.3
# 2      1.5
# 3      2.0
# 4      2.2
# 5      2.9
# 6      3.0
# 7      3.2
# 8      3.2
# 9      3.7
# 10     3.9
# 11     4.0
# 12     4.0
# 13     4.1
# 14     4.5
# 15     4.9
# 16     5.1
# 17     5.3
# 18     5.9
# 19     6.0
# 20     6.8
# 21     7.1
# 22     7.9
# 23     8.2
# 24     8.7
# 25     9.0
# 26     9.5
# 27     9.6
# 28    10.3
# 29    10.5
# Name: YearsExperience, dtype: float64
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
x_mean = X.mean()
y_mean = y.mean()

print("Mean of X:" , x_mean)
print("Mean of Y:" , y_mean)
# Out:
# Mean of X: 5.3133333333333335
# Mean of Y: 76003.0

# %%
# 1. Calculate the numerator and denominator for the slope formula
numerator = ((X - x_mean) * (y - y_mean)).sum()
denominator = ((X - x_mean) ** 2).sum()

# 2. Fix the typo: change 'numenator' to 'numerator'
m = numerator / denominator

# 3. Print the final calculated slope
print(f"Slope (m): {m:.5f}")
# Out:
# Slope (m): 9449.96232

# %%
c = y_mean - (m * x_mean)
print("Intercept (c):", c)
# Out:
# Intercept (c): 25792.20019866869

# %%
salary = m * X + c
df["Salary"] = salary
print(df)
# Out:
#     YearsExperience         Salary
# 0               1.1   36187.158752
# 1               1.3   38077.151217
# 2               1.5   39967.143681
# 3               2.0   44692.124842
# 4               2.2   46582.117306
# 5               2.9   53197.090931
# 6               3.0   54142.087163
# 7               3.2   56032.079627
# 8               3.2   56032.079627
# 9               3.7   60757.060788
# 10              3.9   62647.053252
# 11              4.0   63592.049484
# 12              4.0   63592.049484
# 13              4.1   64537.045717
# 14              4.5   68317.030645
# 15              4.9   72097.015574
# 16              5.1   73987.008038
# 17              5.3   75877.000502
# 18              5.9   81546.977895
# 19              6.0   82491.974127
# 20              6.8   90051.943985
# 21              7.1   92886.932681
# 22              7.9  100446.902538
# 23              8.2  103281.891235
# 24              8.7  108006.872395
# 25              9.0  110841.861092
# ...

# %%
ss_res = ((y - salary) ** 2).sum()
ss_tot = ((y - y.mean()) ** 2).sum()
r2_score = 1 - (ss_res / ss_tot)
print("R2 Score:", round(r2_score, 4))
# Out:
# R2 Score: 0.957

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\ramba\OneDrive\Documents\AI\SelfPracticeSalary_Data.csv")

# %%
x = data['YearsExperience']

x.head()
# Out:
# 0    1.1
# 1    1.3
# 2    1.5
# 3    2.0
# 4    2.2
# Name: YearsExperience, dtype: float64

# %%
y = data['Salary']
y.head()
# Out:
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# Name: Salary, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7, random_state=42)

# %%
print(len(x))
# Out:
# 30

# %%
x_train=x_train.to_numpy()[:,np.newaxis]
x_test=x_test.to_numpy()[:,np.newaxis]

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train.reshape(-1, 1), y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
c = [i for i in range(1,len(y_test)+1,1)]
plt.plot(c,y_test,color='r',linestyle='-')
plt.plot(c,y_pred,color='b',linestyle='-')
plt.xlabel('Salary')
plt.ylabel('index')
plt.title('Prediction')
plt.show()

# %%
from sklearn.metrics import r2_score, mean_squared_error
