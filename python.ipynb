# %%
print("Hello World!")

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
#camel case
sumOfTwoNumbers = 8 + 2
print(sumOfTwoNumbers)
# Out:
# 10

# %%
#snake case
sum_of_two_numbers = 6 + 3
print(sum_of_two_numbers)
# Out:
# 9

# %%
#paskal case
SumOfTwoNumbers = 8 + 2
print(SumOfTwoNumbers)
# Out:
# 10

# %%
x,y,z = 2,3,6
print(x)
print(y)
print(z)
# Out:
# 2
# 3
# 6

# %%
x = y= z = 9
print(x)
print(y)
print(z)
# Out:
# 9
# 9
# 9

# %%
a = 50000
b = 75000
c = 65000
print(a + b + c)
# Out:
# 190000

# %%
a = "Secure123"
print(a.length())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 a = "Secure123"
# ----> 2 print(a.length())
#
# AttributeError: 'str' object has no attribute 'length'

# %%
a = "Secure123"
print(len(a))
# Out:
# 9

# %%
a = [1,2,3]
b = [1,2,3]
c = a
print(a is b)
print( a is c)
# Out:
# False
# True

# %%
# Membership operator
a = [1,2,3,4,5,6]
b = 6
print(b in a)
# Out:
# True

# %%
a = [1,2,3,4,5,6]
b = 8
print(b in a)
# Out:
# False

# %%
a = [1,2,3,4,5,6]
b = 6
print(b not  in a)
# Out:
# False

# %%
a = "Hello"
b = 'Hello'
print(type(a))
print(b)
print(type(b))
print(len(a))
# Out:
# <class 'str'>
# Hello
# <class 'str'>
# 5

# %%
a = "python"
print(a[-6])
# Out:
# p

# %%
a = "python"
print(a[2:])
print(a[4:])
print(a[::-1])
# Out:
# thon
# on
# nohtyp

# %%
a = "python"
b = a.capitalize()
c = a.casefold()
print(a)
print(b)
print(c)
# Out:
# python
# Python
# python

# %%
a = "Hello"
b = 8
print(a *b )
# Out:
# HelloHelloHelloHelloHelloHelloHelloHello

# %%
year = 2024
year2 = 2025
a = 'Happy New Year {} {}'
print(a.format(year2,year))
# Out:
# Happy New Year 2025 2024

# %%
year = 2024
year2 = 2025
a = f'Happy New Year {year2}'
print(a.format(year2,year))
# Out:
# Happy New Year 2025

# %%
a = "Hai"
b = "123"
c = a.join(b)
print(c)
# Out:
# 1Hai2Hai3

# %%
a = "PYTHON"
b = a.lower()
print(b)
# Out:
# python

# %%
a = "Java is a programmming language"
b = a.replace('Java','Python')
print(b)
# Out:
# Python is a programmming language

# %%
a = "Javaisaprogramminglanguage"
b = a.split('a')
print(b)
# Out:
# ['J', 'v', 'is', 'progr', 'mmingl', 'ngu', 'ge']

# %%
a = "Python is a programming language"
b = a.swapcase()
print(b)
# Out:
# pYTHON IS A PROGRAMMING LANGUAGE

# %%
password = "Secure123"
if(len(password) >= 8):
    print("password is valid")
else:
    print("password is not valid")
# Out:
# password is valid

# %%
student = "Alice"
maths = 85
science = 90
message = f"{student} scored {maths} in maths and {science} in science"
print(message)
# Out:
# Alice scored 85 in maths and 90 in science

# %%
#45,8,500
book = 45
numberOfBooks = 8
price = 500
change = price - (book * numberOfBooks)
print(change)
# Out:
# 140

# %%
a = 10
if a != 0: 
    print("Positive Number")
    if a%2 == 0:
        print("Even Number")
    else:
        print("Odd Number")
else:
    print("Neutral Number")
# Out:
# Positive Number
# Even Number

# %%
a = "python"
for j in a:
    print(j)
# Out:
# p
# y
# t
# h
# o
# n

# %%
#while loop
a = "python"
i = 0
while i < len(a):
    print(i)
    i += 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(3):
    print(i)
    for j in range(2):
      print(j)
# Out:
# 0
# 0
# 1
# 1
# 0
# 1
# 2
# 0
# 1

# %%
a = int (input("Enter a value"))
b = int(input("Enter another value"))
print(a+b)
# Out:
# 30

# %%
#Ternary Operator
num = 7
result = "Even" if num % 2 == 0 else "Odd"

# %%
class Dog:
    attribute1 = "mammal"
    def __init__(self,name):
        self.name = name

# %%
#creating instances
daredevil = Dog("DareDevil")
maxx = Dog("Maxx")

# %%
class Parent:
    def __init__(self,name,age):
        self.name = name
        self.age = age
        def display_person(self):
            print(f"Name:{self.name}")
            pri

# %%
from abc import ABC ,abstractmethod
class JuiceMachine(ABC):
    @abstractmethod
    def make_juice(self):
        pass
class OrangeJuiceMchine(JuiceMachine):
    def make_juice(self):
        print("Making orange juice...")

# %%
# !pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/17.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/17.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/17.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/17.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/17.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/17.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/17.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/17.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/17.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/17.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/17.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/17.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/17.7 MB ? eta -:--:--
# ...

# %%
import mysql.connector

mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Aruna@2006"
)
mycursor = mydb.cursor()
mycursor.execute("CREATE DATABASE mydatabase")

# %%
import mysql.connector
conn=mysql.connector.connect(host="localhost",user="root",password="Aruna@2006")
c=conn.cursor()
c.execute("show databases ")
for i in c:
    print(i)
# Out:
# ('information_schema',)
# ('mydatabase',)
# ('mysql',)
# ('performance_schema',)
# ('sakila',)
# ('sys',)
# ('world',)

# %%
import mysql.connector
db=mysql.connector.connect(
    host="localhost",
    user="root",
    password="Aruna@2006",
    database="mydatabase"
)

c=db.cursor()

sql ='''CREATE TABLE ATAL12345(
Rno int not null primary key,
Name varchar(30) not null,
Branch CHAR(10),
Percentage FLOAT,
Email varchar(50),
MobilNo int)'''

c.execute(sql)

# %%
c.execute("SHOW TABLES")
for i in c:
    print(i)
# Out:
# ('atal12345',)
